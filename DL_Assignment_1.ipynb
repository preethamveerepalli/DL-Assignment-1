# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from tensorflow.keras.backend import sigmoid


# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to [0, 1]
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Define the model architecture
#model = keras.Sequential([layers.Flatten(input_shape=(28, 28)),layers.Dense(128, activation="sigmoid"),layers.Dense(10)])
model = keras.Sequential()
model.add(layers.Flatten())
model.add (layers.Dense(128,activation='sigmoid'))
model.add (layers.Dense(64,activation='sigmoid'))
model.add (layers.Dense(10))
# Compile the model
model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"],
)

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1500/1500 [==============================] - 15s 5ms/step - loss: 0.5281 - accuracy: 0.8675 - val_loss: 0.2338 - val_accuracy: 0.9323
# Epoch 2/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2039 - accuracy: 0.9410 - val_loss: 0.1742 - val_accuracy: 0.9483
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1430 - accuracy: 0.9575 - val_loss: 0.1309 - val_accuracy: 0.9618
# Epoch 4/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1079 - accuracy: 0.9676 - val_loss: 0.1160 - val_accuracy: 0.9656
# Epoch 5/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0829 - accuracy: 0.9753 - val_loss: 0.1159 - val_accuracy: 0.9676
# Epoch 6/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0663 - accuracy: 0.9808 - val_loss: 0.0969 - val_accuracy: 0.9709
# Epoch 7/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0534 - accuracy: 0.9846 - val_loss: 0.0922 - val_accuracy: 0.9723
# Epoch 8/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0426 - accuracy: 0.9879 - val_loss: 0.0992 - val_accuracy: 0.9712
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0346 - accuracy: 0.9903 - val_loss: 0.0874 - val_accuracy: 0.9747
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0277 - accuracy: 0.9923 - val_loss: 0.0913 - val_accuracy: 0.9735

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (32, 784)                 0
#
#  dense (Dense)               (32, 128)                 100480
#
#  dense_1 (Dense)             (32, 64)                  8256
#
#  dense_2 (Dense)             (32, 10)                  650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
#MODEL ev
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
print("Train accuracy:", train_acc)


test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print("Test accuracy:", test_acc)
# Out:
# 1875/1875 - 3s - loss: 0.0337 - accuracy: 0.9914 - 3s/epoch - 2ms/step
# Train accuracy: 0.9913666844367981
# 313/313 - 1s - loss: 0.0791 - accuracy: 0.9770 - 664ms/epoch - 2ms/step
# Test accuracy: 0.9769999980926514

# %%
#computatinal graphs of model
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %%
#computatinal graphs of model
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()

# %%
plt.plot(history.history["loss"])
plt.title("TRAIN LOSS")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
plt.plot(history.history["val_loss"])
plt.title("TEST LOSS")
plt.ylabel("TEST_Loss")
plt.xlabel("Epoch")
plt.show()
